# %% [markdown]
# <a href="https://colab.research.google.com/github/2017130715/class2021Spring/blob/main/20210331_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Duration
#  a - 0.410756 sec/
#  e - 0.310 sec
#
# *Pitch
#  a - 105.7 Hz/
#  e - 100.9 Hz
#
# *Intensity
#  a - 89.63 dB/
#  e - 82.05 dB
#
# *Formant
#  a - first:933.8 Hz, second:1223 Hz/
#  e - first:548.7 Hz, second:1896 Hz
